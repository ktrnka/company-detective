# %%
from search import search
from pprint import pprint

res = search("site:glassdoor.com 98point6")
pprint(res)
# Out:
# {'context': {'title': 'company_detective'},
#  'items': [{'displayLink': 'www.glassdoor.com',
#             'formattedUrl': 'https://www.glassdoor.com/Reviews/98point6-Reviews-E1181484.htm',
#             'htmlFormattedUrl': 'https://www.glassdoor.com/Reviews/<b>98point6</b>-Reviews-E1181484.htm',
#             'htmlSnippet': '<b>98point6</b> has an overall rating of 3.8 out '
#                            'of 5, based on over 178 reviews left anonymously '
#                            'by employees. 61% of employees would recommend '
#                            'working at <b>98point6</b> to&nbsp;...',
#             'htmlTitle': '<b>98point6</b> Reviews: What Is It Like to Work At '
#                          '<b>98point6</b>? | Glassdoor',
#             'kind': 'customsearch#result',
#             'link': 'https://www.glassdoor.com/Reviews/98point6-Reviews-E1181484.htm',
#             'pagemap': {'breadcrumb': [{'title': 'Reviews', 'url': 'Reviews>'},
# ...

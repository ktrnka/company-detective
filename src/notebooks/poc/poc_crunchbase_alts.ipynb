# %%
from core import init

init()

# %%
url = "https://leadiq.com/c/point-technologies-inc/5a1d98e42300005400877e7d"

# Version 2: A rewrite

import os
from scrapfly import ScrapeApiResponse, ScrapeConfig, ScrapflyClient

SCRAPFLY = ScrapflyClient(key=os.environ["SCRAPFLY_KEY"])
BASE_CONFIG = {
    # Crunchbase.com requires Anti Scraping Protection bypass feature.
    # for more: https://scrapfly.io/docs/scrape-api/anti-scraping-protection
    "asp": True,
    # "format": "markdown",
    "cache": True,
}


scrapfly_result = await SCRAPFLY.async_scrape(ScrapeConfig(url, **BASE_CONFIG))

# %%
from pprint import pprint

pprint(scrapfly_result.content)
# Out:
# ('<!DOCTYPE html><html lang="en"> <head><meta charset="UTF-8"><meta '
#  'name="viewport" content="width=device-width, initial-scale=1, '
#  'minimum-scale=1, maximum-scale=5"><link rel="icon" type="image/png" '
#  'href="https://assets-global.website-files.com/60819f9be381394642b5659e/60dccb991e7b7efb0eb153f5_leadiq-icon.png"><!-- '
#  'Preload --><link rel="preload" as="image" fetchpriority="high" '
#  'href="/_assets/strip-texture.webp" media="(min-width: 901px)" '
#  'type="image/webp"><!-- Google Tag Manager --><!-- Fonts --><title>98point6 '
#  'Technologies Inc. Company Overview, Contact Details &amp; Competitors | '
#  'LeadIQ</title><link rel="stylesheet" '
#  'href="/_assets/fonts/Circular/circular.css"><!--[--><meta name="description" '
#  'content="Learn more about 98point6 Technologies Inc.&#39;s company details, '
#  'contact information, competitors, and more. Find accurate contact data '
#  'easily with LeadIQ. Book a demo today."><meta name="og:description" '
#  'content="Learn more about 98point6 Technologies Inc.&#39;s company details, '
#  'contact information, competitors, and more. Find accurate contact data '
#  'easily with LeadIQ. Book a demo today."><meta name="keywords" '
#  'content="98point6 technologies inc. phone number,98point6 technologies inc. '
#  'location,98point6 technologies inc. contact number,98point6 technologies '
#  'inc. corporation,98point6 technologies inc. headquarters,98point6 '
#  'technologies inc. contact,98point6 technologies inc. contact '
#  'details,98point6 technologies inc. corporation headquarters,98point6 '
#  'technologies inc. revenue,98point6 technologies inc. main office,98point6 '
#  'technologies inc. competitors,98point6 technologies inc. industry,98point6 '
#  'technologies inc. headquarters address and phone number,98point6 '
#  'technologies inc. company '
#  'overview"><!--]--><style>a{color:inherit;text-decoration:inherit}body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:sans-serif;font-feature-settings:"clig" '
#  'off,"liga" '
#  'off;font-smooth:never;margin:0}dd{margin-left:16px}h3{color:#063c4d}a:hover{color:#00d586}button{background-color:var(--buttonColor);border:2.458px '
#  'solid '
#  'var(--buttonColor);border-radius:6.554px;color:#144042;cursor:pointer;font-size:13.927px;font-weight:700;padding:calc(var(--paddingSmall) '
#  '- 2*2.458px);transition:all '
#  '.35s}button:hover{scale:1.025}button.outlined{background:transparent;border-color:#063c4d}button.outlined:hover{border-color:var(--buttonColor);background-color:var(--buttonColor)}h2{font-size:24px;font-weight:700;margin-bottom:30px;position:relative}hgroup{position:relative}hgroup>h2{margin-bottom:11px;margin-top:inherit}ul{list-style:none;margin:0;padding:0}[data-filter-target] '
#  '[data-filter-candidate]:not(.match){display:none!important}[data-observe-intersection][data-intersect-fail] '
#  '[data-observe-outlet]:after{content:attr(data-fallback)}[data-observe-outlet] '
#  'strong{display:block;font-size:16px;font-weight:700;line-height:19.2px;margin-bottom:4px}[data-observe-outlet] '
#  'p{font-weight:400;line-height:16.8px;margin-bottom:24px}[data-observe-outlet] '
#  'p:first-child{margin-top:45px}[data-observe-outlet] '
#  'p:last-child{margin:0}.enumerated+.enumerated:before{content:", '
#  '"}.enumerated+.enumerated[data-separator]:before{content:attr(data-separator)}.fonts-loaded-roman '
#  'body{font-family:CircularRoman}.fonts-loaded '
#  'body{font-family:CircularStd}.hide{display:none!important}.page{background-color:var(--backgroundColor);color:var(--foregroundColor);font-size:14px;line-height:1.2;padding:var(--headerSize) '
#  'var(--pagePadding) calc(var(--pagePadding) / 2) '
#  'var(--pagePadding);position:relative}.strip{height:88.71px}.strip:after,.strip:before{content:"";background-position:50%;background-repeat:no-repeat;background-size:cover;display:block;height:317px;left:0;position:absolute;width:100%}.strip:before{background:linear-gradient(90deg,#00a562 '
#  '-3.51%,#0e566c '
#  '99.9%)}.strip.blue:before{background:linear-gradient(90deg,#005772 '
#  '-3.51%,#00ace2 '
#  '99.9%)}.strip:after{opacity:0;mix-blend-mode:multiply;transition:opacity '
#  '.25s '
#  'ease-in}.strip.blue:after{mix-blend-mode:unset;background-size:contain;background-position:right '
#  'center}.strip-fg{margin:0 '
#  'auto;max-width:1440px;position:relative}:is(h1,h2,h3){line-height:normal}:is(h1,h2){color:#042d3a}:is(:not(hgroup)>h2,hgroup):after{content:url(/_assets/h2-deco.svg);bottom:-19px;left:0;position:absolute;stroke:#00d586;stroke-width:2px}@keyframes '
#  'spin{to{rotate:360deg}}@media (max-width: 900px){.container{--pagePadding: '
#  '20px '
#  '!important}.hide-on-mobile{display:none!important}.strip{height:30px}}@media '
#  '(min-width: '
#  '901px){.strip:after{background-image:url(/_assets/strip-texture.webp);opacity:1}.strip.blue:after{background-image:url(/_assets/hero-art.webp);opacity:1}}\n'
#  '.arrow[data-v-c6d691d1]{margin-left:6px}.card[data-v-c6d691d1]:not(.layout){background:#fff;border:1px '
#  'solid '
#  'var(--borderColor);border-radius:12.691px;box-sizing:border-box;padding:var(--paddingLarge) '
#  'var(--paddingMedium)}.card.hero[data-v-c6d691d1]{border:2px solid '
#  '#063C4D}.card.snug[data-v-c6d691d1]{padding:var(--paddingSmall)}.card.span[data-v-c6d691d1]{height:100%}.card+.card[data-v-c6d691d1]{margin-top:24px}.card[data-v-c6d691d1]>*:first-child{margin-top:0}.card[data-v-c6d691d1]>*:last-child{margin-bottom:0}.cta[data-v-c6d691d1]{font-size:12px;font-weight:450}.cta[data-v-c6d691d1]:has(*:not(:empty)){margin-top:36px}\n'
#  '.link[data-v-f236162f]{flex-shrink:0}button[data-v-f236162f]{padding-left:32px;padding-right:32px}h3[data-v-f236162f]{color:inherit!important;font-size:28px;font-weight:600;margin:0 '
#  '0 '
#  '8px}p[data-v-f236162f]{color:#ffffffb9;font-size:16px;margin:0}section[data-v-f236162f]{background:linear-gradient(90deg,#032e3b '
#  '-3.51%,#0e566c '
#  '99.9%);background-size:cover;border-radius:12.691px;color:#fff;padding:32px '
#  '64px}.bottom[data-v-f2ce2197]{height:var(--headerSize)}.container[data-v-f2ce2197]{color:#576f76;margin:auto;max-width:1440px;padding:0 '
#  'var(--pagePadding)}.cta[data-v-f2ce2197]{padding-bottom:48px;padding-top:48px}.noflex[data-v-f2ce2197]{flex-shrink:0}.wrap[data-v-f2ce2197]{background:#fff;border-top:1px '
#  'solid #dae2e3}.top[data-v-f2ce2197]{padding-bottom:calc(.875 * '
#  'var(--pagePadding));padding-top:calc(1.625 * '
#  'var(--pagePadding))}li[data-v-f2ce2197]{margin-bottom:20px}li[data-v-f2ce2197]:first-child{color:#063c4d;font-size:20px;font-weight:500;line-height:22px;margin-bottom:38px}@media '
#  '(max-width: '
#  '900px){.top[data-v-f2ce2197]{flex-wrap:wrap!important;justify-content:center!important}.top[data-v-f2ce2197]>*{flex:0 '
#  '0 calc(50% - '
#  '8px)}}a[data-v-0020eaf8]{white-space:nowrap}button[data-v-0020eaf8]{padding-left:32px;padding-right:32px}.actions[data-v-0020eaf8]{flex-grow:0!important;min-width:auto!important}.container[data-v-0020eaf8]{height:var(--headerSize);max-width:1440px;padding:0 '
#  'var(--pagePadding)}.learnmore[data-v-0020eaf8]{color:#063c4d}.wrap[data-v-0020eaf8]{background:#fff;box-shadow:0 '
#  '4px 16px -6px '
#  '#00000026;position:fixed;z-index:1;width:100%}.container[data-v-08ed9419]{--backgroundColor: '
#  'var(--12c3c512);--borderColor: var(--99d80958);--buttonColor: '
#  'var(--1d933c0e);--foregroundColor: var(--c05413c6);--headerSize: '
#  'calc(var(--97e0b05e) * 1px);--paddingLarge: calc(var(--bbf6d6e6) * '
#  '1px);--paddingMedium: calc(var(--bf163f3a) * 1px);--paddingSmall: '
#  'calc(var(--bb27234e) * 1px);--pagePadding: calc(var(--1268b73f) * 1px)}\n'
#  'a[data-v-78028742]{padding-bottom:11px}a[data-active][data-v-78028742]{box-shadow:inset '
#  '0 -5px '
#  '#00d586;padding-bottom:12px;position:relative;top:1px}img[data-v-78028742]{max-height:17px}nav[data-v-78028742]{border-bottom:1px '
#  'solid '
#  '#042D3A}li[data-v-512dd728]{flex-grow:0}.company-overview[data-v-00c368dc]{display:grid;gap:18px;grid-template-areas:"hero '
#  'hero hero" "highlight-left highlight-center highlight-right" "content-center '
#  'content-center ." "content-rest content-rest sidebar-top" "content-rest '
#  'content-rest sidebar-middle" "content-rest content-rest sidebar-bottom" '
#  '"content-rest content-rest .";grid-template-columns:1fr 1fr '
#  '1fr;grid-template-rows:max-content max-content max-content max-content '
#  'max-content max-content 1fr;margin:0 '
#  'auto;max-width:1440px}.content-center[data-v-00c368dc]{grid-area:content-center;margin-bottom:7px}.content-rest[data-v-00c368dc]{grid-area:content-rest}.hero[data-v-00c368dc]{grid-area:hero;margin-bottom:36px}.highlight-left[data-v-00c368dc]{grid-area:highlight-left;margin-bottom:36px}.highlight-center[data-v-00c368dc]{grid-area:highlight-center;margin-bottom:36px}.highlight-right[data-v-00c368dc]{grid-area:highlight-right;margin-bottom:36px}.sidebar-top[data-v-00c368dc]{grid-area:sidebar-top}.sidebar-middle[data-v-00c368dc]{grid-area:sidebar-middle}.sidebar-bottom[data-v-00c368dc]{grid-area:sidebar-bottom}@media '
#  '(max-width: '
#  '900px){.company-overview[data-v-00c368dc]{grid-template-areas:"hero" '
#  '"highlight-left" "highlight-center" "highlight-right" "sidebar-top" '
#  '"sidebar-middle" "sidebar-bottom" "content-center" '
#  '"content-rest";grid-template-columns:1fr;grid-template-rows:max-content '
#  'max-content max-content max-content max-content max-content max-content '
#  'max-content '
#  '1fr}}ul[data-v-fe82d1ea]{display:grid;gap:12px;grid-template-columns:repeat(3,1fr);justify-content:space-between}li[data-v-fe82d1ea]{border:1px '
#  'solid '
#  '#DAE2E3;border-radius:12.691px;padding:16px;min-width:0}h3[data-v-fe82d1ea]{color:#042d3a;margin:0;overflow:hidden;font-weight:700;text-overflow:ellipsis;white-space:nowrap;width:100%}div[data-v-fe82d1ea]{min-width:0}img[data-v-fe82d1ea]{border-radius:10px}.separator[data-v-fe82d1ea]:last-child{display:none}@media '
#  '(max-width: '
#  '900px){ul[data-v-fe82d1ea]{grid-template-columns:1fr}}li+li[data-v-0af0051d]{margin-top:32px}em[data-v-2cbc9691]{color:#042d3a;display:inline-block;font-size:32px;font-style:normal;font-weight:700;line-height:normal;margin-bottom:10px}li[data-v-2cbc9691]{margin:8px '
#  '0;padding:8px '
#  '0;position:relative}li+li[data-v-2cbc9691]{margin-top:16px}li+li[data-v-2cbc9691]:before{content:"";background:#dae2e3;display:block;height:1px;position:absolute;top:-8px;width:100%}p[data-v-2cbc9691]{margin:0}a:hover>h3[data-v-9d6c8b2a]{color:#00d586}h2[data-v-9d6c8b2a]{margin-top:0}h3[data-v-9d6c8b2a]{color:#042d3a;font-size:16px;margin:0}img[data-v-9d6c8b2a]{flex-shrink:0;width:31.39px}li+li[data-v-9d6c8b2a]{margin-top:24px}p[data-v-9d6c8b2a]{margin:4px '
#  '0 0}.container[data-v-9d6c8b2a]:not(.headlines) '
#  'h2{margin-bottom:44px}.headlines '
#  'h3[data-v-9d6c8b2a]{font-size:14px}.info[data-v-9d6c8b2a]{color:#85959a;font-size:12px;margin-top:10px}dd[data-v-61c63360]{color:#355964;font-weight:400;margin:0}dt[data-v-61c63360]{color:#042d3a;flex-shrink:0;font-weight:700}.item+.item[data-v-61c63360]{margin-top:16px}li[data-v-a172066e]{border-radius:12.691px;border:1px '
#  'solid '
#  '#DAE2E3;box-sizing:border-box;padding:16px;text-align:center}ul[data-v-a172066e]{display:grid;gap:12px;grid-template-columns:repeat(4,1fr);grid-template-rows:repeat(2,max-content)}.category[data-v-a172066e]{color:#355964;font-size:14px;font-weight:450;line-height:1.4}.name[data-v-a172066e]{color:#042d3a;font-size:16px;font-weight:700;line-height:1.4}@media '
#  '(max-width: '
#  '900px){ul[data-v-a172066e]{grid-template-columns:repeat(2,1fr)}}.loading[data-v-c617f00a]{height:100%}.name[data-v-c617f00a]{font-weight:700}[data-v-c617f00a] '
#  '[data-observe-intersection]:not(:is([data-intersect-fail],[data-intersect-success])) '
#  '[data-observe-outlet]{height:200px}\n'
#  'button[data-v-d599a7a5]{font-size:20px!important;padding-left:32px;padding-right:32px}h3[data-v-d599a7a5]{color:inherit!important;font-size:31.573px;font-weight:600;margin:0 '
#  '0 16px}p[data-v-d599a7a5]{font-size:22.552px;margin:0 0 '
#  '32px}section[data-v-d599a7a5]{background:#019e63 url(/_assets/cta-bg.webp) '
#  'no-repeat;background-size:cover;border-radius:12.691px;color:#fff;font-size:22.552px;padding:64px '
#  '32px}img[data-v-89f8470f]{animation:spin 1.2s linear '
#  'infinite;aspect-ratio:1;width:50px}[data-v-e5f646e3] '
#  'progress{appearance:none;height:13px}[data-v-e5f646e3] '
#  'progress::-webkit-progress-bar{background:#8ee6c5;border-radius:5px;overflow:hidden}[data-v-e5f646e3] '
#  'progress::-webkit-progress-value{background:#00c37b}table[data-v-e5f646e3]{border-spacing:0;margin-top:25px;width:100%}[data-v-e5f646e3] '
#  'thead{color:#063c4d;font-weight:700}[data-v-e5f646e3] thead '
#  'td{border-bottom:1px solid #DAE2E3}[data-v-e5f646e3] td{padding:17px '
#  '0}[data-v-e5f646e3] '
#  '.percent{color:#00d586;display:inline-block;font-weight:450;text-align:right;width:35px}.separator:not(:last-child) '
#  'td[data-v-055562da]{border-bottom:1px solid #DAE2E3}\n'
#  'pre[data-v-7acee664]{font-family:inherit;white-space:pre-wrap}\n'
#  'a[data-v-6c772ee5]:not(:has(img))+a:before{content:", '
#  '"}h1[data-v-565fa535]{font-size:48px;font-weight:700;margin:0 0 '
#  '14px}img[data-v-565fa535]{aspect-ratio:1;width:76.747px}.bottom[data-v-565fa535]{margin-top:32px}.content[data-v-565fa535]{flex:1;line-height:1.4}.info[data-v-565fa535]{font-size:12px}.info[data-v-565fa535]>*+*{padding-left:18.40918px;position:relative;text-align:center}.info[data-v-565fa535]>*+*:before{content:"";aspect-ratio:1;background:#d9d9d9;border-radius:50%;bottom:0;display:inline-block;margin:auto '
#  '8px;left:0;top:0;position:absolute;width:2.40918px}.social[data-v-565fa535]{flex-grow:0!important;min-width:auto!important}@media '
#  '(max-width: '
#  '900px){.bottom[data-v-565fa535]{flex-direction:column!important;gap:18px!important}.buttons[data-v-565fa535]{flex-direction:column!important}img[data-v-565fa535]{float:right}.social[data-v-565fa535]{align-self:flex-end}.wrap[data-v-565fa535]{display:block!important}}details[data-v-95b2361a]{box-sizing:border-box;height:65px;padding:24px '
#  '0}details+details[data-v-95b2361a]{border-top:1px solid '
#  '#DAE2E3}details[open][data-v-95b2361a]{height:auto}details[open]>summary[data-v-95b2361a]{margin-bottom:11px}details[open] '
#  'img[data-open][data-v-95b2361a]{display:none}details:not([open]) '
#  'img[data-v-95b2361a]:not([data-open]){display:none}h3[data-v-95b2361a]{flex:1;font-size:14px;margin:0}summary[data-v-95b2361a]{cursor:pointer;user-select:none}\n'
#  '.end[data-v-82abe972]:first-child:before{content:"<"}.start[data-v-82abe972]:last-child:after{content:"+"}.start+.end[data-v-82abe972]:before{content:" '
#  '- "}\n'
#  '.details[data-v-2c5e8248]{color:#85959a;font-size:12px;margin-top:9px}.info[data-v-2c5e8248]{flex:1}.info.grid[data-v-2c5e8248]{align-items:center;display:grid;gap:32px;grid-template-columns:var(--6136c0c8)}.info.grid[data-v-2c5e8248]>*:not(:first-child){justify-self:center;text-align:center}.item.mobile[data-v-2c5e8248]{flex:none!important}.location+.location[data-v-2c5e8248]:before{content:", '
#  '"}.name[data-v-2c5e8248]{overflow:hidden;text-overflow:ellipsis;white-space:nowrap;width:100%}.separator[data-v-2c5e8248]{background-color:#dae2e3;flex-shrink:0;height:14px;width:1px}.title[data-v-2c5e8248]{display:-webkit-box;overflow:hidden;-webkit-box-orient:vertical;-webkit-line-clamp:2}@media '
#  '(max-width: '
#  '900px){.info.grid[data-v-2c5e8248]{grid-template-columns:repeat(2,minmax(0,1fr))}}\n'
#  '</style><script '
#  'type="module">document.querySelectorAll("[data-filter]").forEach(t=>{const '
#  'e=t.querySelector("[data-filter-input]");if(e==null)return;const '
#  'a=t.querySelector("[data-filter-target]");if(a==null)return;const '
#  'n=t.querySelector("[data-filter-initial]"),i=t.querySelector("[data-filter-load]"),o=t.querySelector("[data-filter-nomatch]"),s=a.querySelectorAll("[data-filter-candidate]"),c=Array.from(s).map(r=>r.getAttribute("data-regex")).map(r=>r!=null?new '
#  'RegExp(r):null);async function d(){if(e==null)return;const '
#  'r=u(),m=e.value.trim();if(m==="")return '
#  'n?.classList.remove("hide"),o?.classList.add("hide"),a?.classList.add("hide"),r();n?.classList.add("hide"),o?.classList.add("hide"),a?.classList.add("hide"),i?.classList.remove("hide"),await '
#  'new Promise(l=>setTimeout(l,500+Math.random()*250|0));let f=!1;for(let '
#  'l=0;l<s.length;l++){const '
#  'w=c[l]?.test(m);s[l].classList[w?"add":"remove"]("match"),f=f||w===!0}return '
#  'i?.classList.add("hide"),f?(o?.classList.add("hide"),a?.classList.remove("hide")):(o?.classList.remove("hide"),a?.classList.add("hide")),r()}function '
#  'u(){const r=window.scrollY;return '
#  'function(){window.scrollTo(window.scrollX,r)}}e.addEventListener("keyup",r=>r.key==="Enter"&&d()),t.querySelector("[data-filter-trigger]")?.addEventListener("click",d)});const '
#  'g=document.querySelectorAll("[data-observe-intersection]");if(g.length){const '
#  't=new IntersectionObserver(async e=>{for(const a of '
#  'e){const{target:n,isIntersecting:i}=a;if(!i)return;t.unobserve(n);const '
#  'o=n.getAttribute("data-endpoint"),s=n.querySelector("[data-observe-outlet]");if(o==null||s==null)return;const '
#  'c=new URL(window.location.href);c.hash="";const d=new '
#  'URL(o,(c+"/").replace(/\\/\\/$/,"/"));try{const u=await '
#  'fetch(d);if(!u.ok)throw new '
#  'Error;n.setAttribute("data-intersect-success",""),s.innerHTML=await '
#  'u.text()}catch{n.setAttribute("data-intersect-fail","")}finally{t.unobserve(n)}}});for(const '
#  'e of g)t.observe(e)}const '
#  'y=document.querySelectorAll("a[data-observe-hash]");function h(){const '
#  't=window.location.hash||"#insights";for(const e of y)new '
#  'URL(e.href).hash===t?e.dataset.active="":delete '
#  'e.dataset.active}window.addEventListener("hashchange",h);h();document.querySelectorAll(\'a[href^="#"]\').forEach(t=>{t.addEventListener("click",e=>{e.preventDefault();const '
#  'a=t.getAttribute("href"),n=document.querySelector(a);if(!n)return;const{top:i}=n.getBoundingClientRect();window.scrollTo({top:i+window.scrollY-88,behavior:"smooth"});const '
#  'o=new '
#  'URL(a,window.location.href);window.history.pushState({},"",o.href),h()})});"fonts"in '
#  'document&&document.fonts.load("1em '
#  'CircularRoman").then(t=>{document.documentElement.classList.add("fonts-loaded-roman"),Promise.all([document.fonts.load("300 '
#  '1em CircularStd"),document.fonts.load("500 1em '
#  'CircularStd"),document.fonts.load("600 1em '
#  'CircularStd"),document.fonts.load("800 1em '
#  'CircularStd"),document.fonts.load("italic 1em '
#  'CircularStd"),document.fonts.load("italic 300 1em '
#  'CircularStd"),document.fonts.load("italic 500 1em '
#  'CircularStd"),document.fonts.load("italic 600 1em '
#  'CircularStd"),document.fonts.load("italic 800 1em '
#  'CircularStd")]).then(e=>document.documentElement.classList.add("fonts-loaded"))});window.mutiny=Object.assign({client:Object.assign({identify:()=>{}},window?.mutiny?.client)});(function(t,e,a,n,i){t[n]=t[n]||[],t[n].push({"gtm.start":new '
#  'Date().getTime(),event:"gtm.js"});var '
#  'o=e.getElementsByTagName(a)[0],s=e.createElement(a),c=n!="dataLayer"?"&l="+n:"";s.async=!0,s.src="https://www.googletagmanager.com/gtm.js?id="+i+c,o.parentNode.insertBefore(s,o)})(window,document,"script","dataLayer","GTM-MM5LGCV");\n'
#  '</script></head> <body>   <!--[--><div class="container" data-v-c617f00a '
#  'style="--12c3c512:#FBFBFB;--99d80958:#DAE2E3;--1d933c0e:#FFD265;--c05413c6:#355964;--97e0b05e:80;--bbf6d6e6:32;--bf163f3a:24;--bb27234e:16;--1268b73f:80;" '
#  'data-v-08ed9419><!--[--><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:center;min-width:0;" '
#  'class="wrap" data-v-c617f00a data-v-0020eaf8><!--[--><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:space-between;min-width:0;" '
#  'class="container" data-v-0020eaf8><!--[--><a href="https://leadiq.com/" '
#  'target="_blank" data-v-0020eaf8><img src="/_assets/logo.DuCvgQ6q.svg" '
#  'alt="LeadIQ logo" data-v-0020eaf8></a><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:24px;justify-content:start;min-width:0;" '
#  'class="actions" data-v-0020eaf8><!--[--><a class="learnmore hide-on-mobile" '
#  'href="https://leadiq.com" data-v-0020eaf8>Learn more at LeadIQ.com</a><a '
#  'target="_blank" '
#  'href="https://account.leadiq.com/signup/welcome?utm_source=seo&amp;fp=%2Fsearch%2Fresults%3FcompanyId%3DMergedCompany-5a1d98e42300005400877e7d%26companyName%3D98point6%2BTechnologies%2BInc." '
#  'data-v-0020eaf8><!--[--><button data-v-0020eaf8>Start '
#  'free</button><!--]--></a><!--]--></div><!--]--></div><!--]--></div><div '
#  'class="page" data-v-c617f00a><div class="strip" data-v-c617f00a></div><div '
#  'class="company-overview strip-fg" data-v-c617f00a '
#  'data-v-00c368dc><!--[--><div class="content-center" '
#  'data-v-00c368dc><!--[--><nav '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:space-between;min-width:0;" '
#  'data-v-c617f00a data-v-78028742><!--[--><a '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:6px;justify-content:center;min-width:0;" '
#  'data-observe-hash href="#insights" data-v-78028742><!--[--><img '
#  'alt="Insights icon" src="/_assets/insights.BXfdjR-b.svg" '
#  'data-v-78028742><span data-v-78028742>Insights</span><!--]--></a><a '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:6px;justify-content:center;min-width:0;" '
#  'data-observe-hash href="#similar" data-v-78028742><!--[--><img '
#  'alt="Buildings icon" src="/_assets/similar.DJLfi8zh.svg" '
#  'data-v-78028742><span data-v-78028742>Similar companies</span><!--]--></a><a '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:6px;justify-content:center;min-width:0;" '
#  'data-observe-hash href="#tech" data-v-78028742><!--[--><img alt="Gear icon" '
#  'src="/_assets/tech.wuVjZdnG.svg" data-v-78028742><span data-v-78028742>Tech '
#  'Stack</span><!--]--></a><a '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:6px;justify-content:center;min-width:0;" '
#  'data-observe-hash href="#media" data-v-78028742><!--[--><img alt="Media '
#  'icon" src="/_assets/media.BMJLsbkg.svg" data-v-78028742><span '
#  'data-v-78028742>Media &amp; News</span><!--]--></a><a '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:6px;justify-content:center;min-width:0;" '
#  'data-observe-hash href="#email" data-v-78028742><!--[--><img alt="Envelope '
#  'icon" src="/_assets/email.fZC817ym.svg" data-v-78028742><span '
#  'data-v-78028742>Email Format</span><!--]--></a><a '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:6px;justify-content:center;min-width:0;" '
#  'data-observe-hash href="#faq" data-v-78028742><!--[--><img alt="Chat bubbled '
#  'icon" src="/_assets/faq.Dx15TOQQ.svg" data-v-78028742><span '
#  'data-v-78028742>FAQ</span><!--]--></a><!--]--></nav><!--]--></div><div '
#  'class="content-rest" data-v-00c368dc><!--[--><div class="card" id="insights" '
#  'data-v-c617f00a data-v-c6d691d1><h2 '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-c6d691d1><!--[--><!----><span '
#  'data-v-c6d691d1><!--[-->Insights<!--]--></span><!--]--></h2><!--[--><div '
#  'data-observe-outlet data-v-c617f00a><!--[--><p data-v-c617f00a><strong '
#  'data-v-c617f00a>Acquisition Strategy</strong> 98point6 Technologies has been '
#  'actively acquiring strategic companies like Bright.md to enhance its virtual '
#  'care capabilities, presenting potential partnership opportunities for '
#  'cross-selling services to a larger combined customer base.</p><p '
#  'data-v-c617f00a><strong data-v-c617f00a>Funding and Expansion</strong> With '
#  'recent financing of $32 million and partnerships with organizations like '
#  'MultiCare Health System, 98point6 is in a strong position to expand its '
#  'reach, indicating potential sales opportunities for new clients seeking '
#  'innovative virtual care solutions.</p><p data-v-c617f00a><strong '
#  'data-v-c617f00a>Technology Integration</strong> The tech stack utilized by '
#  '98point6, including tools like HubSpot Chat and Pardot, showcases a '
#  'commitment to leveraging advanced technologies, creating avenues for sales '
#  'discussions around integrated solutions for healthcare organizations.</p><p '
#  'data-v-c617f00a><strong data-v-c617f00a>Key Personnel Impact</strong> The '
#  'appointment of Younggren as president brings significant experience to the '
#  'team, potentially opening doors for sales conversations with prospects '
#  'looking for leadership-backed assurances and tailored virtual care '
#  'services.</p><p data-v-c617f00a><strong data-v-c617f00a>Competitive '
#  'Positioning</strong> In a competitive virtual care market with companies '
#  'like Teladoc Health and Doctor On Demand, 98point6’s innovative approach and '
#  'partnerships set it apart, providing a sales edge for offering '
#  'differentiated and comprehensive virtual care '
#  'solutions.</p><!--]--></div><!--]--><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:space-between;min-width:0;" '
#  'class="cta" data-v-c6d691d1><!--[--><div class="left" '
#  'data-v-c6d691d1><!--[--><!--]--></div><div '
#  'data-v-c6d691d1><!--[--><!--]--><!----></div><!--]--></div></div><div '
#  'class="card" id="similar" data-v-c617f00a data-v-c6d691d1><h2 '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-c6d691d1><!--[--><!----><span data-v-c6d691d1><!--[-->Similar '
#  'companies to <span data-v-c617f00a>98point6 Technologies '
#  'Inc.</span><!--]--></span><!--]--></h2><!--[--><ul data-v-c617f00a '
#  'data-v-fe82d1ea><!--[--><!--[--><li data-v-fe82d1ea><a '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:12px;justify-content:start;min-width:0;" '
#  'href="/c/doctor-on-demand/5a1d9727230000590085bbc4" '
#  'data-v-fe82d1ea><!--[--><!--[--><img alt="Company logo" '
#  'src="https://image-service.leadiq.com/companylogo?linkedinId=3698317" '
#  'height="50" width="50" data-v-fe82d1ea><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:column;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-fe82d1ea><!--[--><h3 data-v-fe82d1ea><span data-v-fe82d1ea>Doctor On '
#  'Demand</span></h3><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-fe82d1ea><!--[--><img alt="People icon" '
#  'src="/_assets/employees.B3ZMbAOv.svg" height="17" data-v-fe82d1ea><span '
#  'data-v-fe82d1ea>1.2K</span><img alt="Vertical separator icon" '
#  'src="/_assets/vseparator.BFuKAh4L.svg" class="separator" '
#  'data-v-fe82d1ea><!--[--><img alt="Revenue icon" '
#  'src="/_assets/revenue.DjNUzFEb.svg" height="17" data-v-fe82d1ea><span '
#  'data-v-fe82d1ea data-v-82abe972><span class="start" '
#  'data-v-82abe972>$50M</span><span class="end" '
#  'data-v-82abe972>$100M</span></span><!--]--><!--]--></div><!--]--></div><!--]--><!--]--></a></li><!--]--><!--[--><li '
#  'data-v-fe82d1ea><a '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:12px;justify-content:start;min-width:0;" '
#  'href="/c/healthtap/5a1d8a512400002400638f32" '
#  'data-v-fe82d1ea><!--[--><!--[--><img alt="Company logo" '
#  'src="https://image-service.leadiq.com/companylogo?linkedinId=1140709" '
#  'height="50" width="50" data-v-fe82d1ea><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:column;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-fe82d1ea><!--[--><h3 data-v-fe82d1ea><span '
#  'data-v-fe82d1ea>HealthTap</span></h3><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-fe82d1ea><!--[--><img alt="People icon" '
#  'src="/_assets/employees.B3ZMbAOv.svg" height="17" data-v-fe82d1ea><span '
#  'data-v-fe82d1ea>163</span><img alt="Vertical separator icon" '
#  'src="/_assets/vseparator.BFuKAh4L.svg" class="separator" '
#  'data-v-fe82d1ea><!--[--><img alt="Revenue icon" '
#  'src="/_assets/revenue.DjNUzFEb.svg" height="17" data-v-fe82d1ea><span '
#  'data-v-fe82d1ea data-v-82abe972><span class="start" '
#  'data-v-82abe972>$10M</span><span class="end" '
#  'data-v-82abe972>$50M</span></span><!--]--><!--]--></div><!--]--></div><!--]--><!--]--></a></li><!--]--><!--[--><li '
#  'data-v-fe82d1ea><a '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:12px;justify-content:start;min-width:0;" '
#  'href="/c/teladoc-health/5a1d94b1540000530078660b" '
#  'data-v-fe82d1ea><!--[--><!--[--><img alt="Company logo" '
#  'src="https://image-service.leadiq.com/companylogo?linkedinId=128505" '
#  'height="50" width="50" data-v-fe82d1ea><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:column;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-fe82d1ea><!--[--><h3 data-v-fe82d1ea><span data-v-fe82d1ea>Teladoc '
#  'Health</span></h3><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-fe82d1ea><!--[--><img alt="People icon" '
#  'src="/_assets/employees.B3ZMbAOv.svg" height="17" data-v-fe82d1ea><span '
#  'data-v-fe82d1ea>5.5K</span><img alt="Vertical separator icon" '
#  'src="/_assets/vseparator.BFuKAh4L.svg" class="separator" '
#  'data-v-fe82d1ea><!--[--><img alt="Revenue icon" '
#  'src="/_assets/revenue.DjNUzFEb.svg" height="17" data-v-fe82d1ea><span '
#  'data-v-fe82d1ea data-v-82abe972><span class="start" '
#  'data-v-82abe972>$1B</span><!----></span><!--]--><!--]--></div><!--]--></div><!--]--><!--]--></a></li><!--]--><!--[--><li '
#  'data-v-fe82d1ea><a '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:12px;justify-content:start;min-width:0;" '
#  'href="/c/amwell/5e7187c01d6f06b38268de75" '
#  'data-v-fe82d1ea><!--[--><!--[--><img alt="Company logo" '
#  'src="https://image-service.leadiq.com/companylogo?linkedinId=64919393" '
#  'height="50" width="50" data-v-fe82d1ea><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:column;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-fe82d1ea><!--[--><h3 data-v-fe82d1ea><span '
#  'data-v-fe82d1ea>Amwell</span></h3><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-fe82d1ea><!--[--><img alt="People icon" '
#  'src="/_assets/employees.B3ZMbAOv.svg" height="17" data-v-fe82d1ea><span '
#  'data-v-fe82d1ea>1.3K</span><img alt="Vertical separator icon" '
#  'src="/_assets/vseparator.BFuKAh4L.svg" class="separator" '
#  'data-v-fe82d1ea><!--[--><img alt="Revenue icon" '
#  'src="/_assets/revenue.DjNUzFEb.svg" height="17" data-v-fe82d1ea><span '
#  'data-v-fe82d1ea data-v-82abe972><span class="start" '
#  'data-v-82abe972>$100M</span><span class="end" '
#  'data-v-82abe972>$1B</span></span><!--]--><!--]--></div><!--]--></div><!--]--><!--]--></a></li><!--]--><!--[--><li '
#  'data-v-fe82d1ea><a '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:12px;justify-content:start;min-width:0;" '
#  'href="/c/memd/5a1d98de2300005a008779a3" data-v-fe82d1ea><!--[--><!--[--><img '
#  'alt="Company logo" '
#  'src="https://image-service.leadiq.com/companylogo?linkedinId=1781889" '
#  'height="50" width="50" data-v-fe82d1ea><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:column;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-fe82d1ea><!--[--><h3 data-v-fe82d1ea><span '
#  'data-v-fe82d1ea>MeMD</span></h3><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-fe82d1ea><!--[--><img alt="People icon" '
#  'src="/_assets/employees.B3ZMbAOv.svg" height="17" data-v-fe82d1ea><span '
#  'data-v-fe82d1ea>63</span><img alt="Vertical separator icon" '
#  'src="/_assets/vseparator.BFuKAh4L.svg" class="separator" '
#  'data-v-fe82d1ea><!--[--><img alt="Revenue icon" '
#  'src="/_assets/revenue.DjNUzFEb.svg" height="17" data-v-fe82d1ea><span '
#  'data-v-fe82d1ea data-v-82abe972><span class="start" '
#  'data-v-82abe972>$10M</span><span class="end" '
#  'data-v-82abe972>$50M</span></span><!--]--><!--]--></div><!--]--></div><!--]--><!--]--></a></li><!--]--><!--[--><li '
#  'data-v-fe82d1ea><a '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:12px;justify-content:start;min-width:0;" '
#  'href="/c/plushcare/5a1d9d8b2300005c008d65c2" '
#  'data-v-fe82d1ea><!--[--><!--[--><img alt="Company logo" '
#  'src="https://image-service.leadiq.com/companylogo?linkedinId=3476726" '
#  'height="50" width="50" data-v-fe82d1ea><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:column;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-fe82d1ea><!--[--><h3 data-v-fe82d1ea><span '
#  'data-v-fe82d1ea>PlushCare</span></h3><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-fe82d1ea><!--[--><img alt="People icon" '
#  'src="/_assets/employees.B3ZMbAOv.svg" height="17" data-v-fe82d1ea><span '
#  'data-v-fe82d1ea>208</span><img alt="Vertical separator icon" '
#  'src="/_assets/vseparator.BFuKAh4L.svg" class="separator" '
#  'data-v-fe82d1ea><!--[--><img alt="Revenue icon" '
#  'src="/_assets/revenue.DjNUzFEb.svg" height="17" data-v-fe82d1ea><span '
#  'data-v-fe82d1ea data-v-82abe972><span class="start" '
#  'data-v-82abe972>$10M</span><span class="end" '
#  'data-v-82abe972>$50M</span></span><!--]--><!--]--></div><!--]--></div><!--]--><!--]--></a></li><!--]--><!--]--></ul><!--]--><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:space-between;min-width:0;" '
#  'class="cta" data-v-c6d691d1><!--[--><div class="left" '
#  'data-v-c6d691d1><!--[--><a target="_blank" '
#  'href="https://account.leadiq.com/signup/welcome?utm_source=seo&amp;fp=%2Fsearch%2Fresults%3FcompanyId%3DMergedCompany-5a1d98e42300005400877e7d%26companyName%3D98point6%2BTechnologies%2BInc." '
#  'data-v-c617f00a><!--[--><button data-v-c617f00a>Explore similar '
#  'companies</button><!--]--></a><!--]--></div><div '
#  'data-v-c6d691d1><!--[--><!--]--><!----></div><!--]--></div></div><div '
#  'class="card" id="tech" data-v-c617f00a data-v-c6d691d1><h2 '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-c6d691d1><!--[--><!----><span data-v-c6d691d1><!--[--><span '
#  'data-v-c617f00a>98point6 Technologies Inc.</span> Tech '
#  'Stack<!--]--></span><!--]--></h2><!--[--><!--[--><p data-v-a172066e><span '
#  'data-v-a172066e>98point6 Technologies Inc.</span> uses 8 technology products '
#  'and services including HubSpot Chat, Pardot, RSS, and more. Explore <span '
#  'data-v-a172066e>98point6 Technologies Inc.</span>&#39;s tech stack '
#  'below.</p><ul data-v-a172066e><!--[--><!--[--><li '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:center;min-width:0;" '
#  'data-v-a172066e><!--[--><div data-v-a172066e><div class="name" '
#  'data-v-a172066e>HubSpot Chat</div><div class="category" data-v-a172066e>Live '
#  'Chat</div></div><!--]--></li><!--]--><!--[--><li '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:center;min-width:0;" '
#  'data-v-a172066e><!--[--><div data-v-a172066e><div class="name" '
#  'data-v-a172066e>Pardot</div><div class="category" '
#  'data-v-a172066e>Marketing</div></div><!--]--></li><!--]--><!--[--><li '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:center;min-width:0;" '
#  'data-v-a172066e><!--[--><div data-v-a172066e><div class="name" '
#  'data-v-a172066e>RSS</div><div class="category" '
#  'data-v-a172066e>Miscellaneous</div></div><!--]--></li><!--]--><!--[--><li '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:center;min-width:0;" '
#  'data-v-a172066e><!--[--><div data-v-a172066e><div class="name" '
#  'data-v-a172066e>Open Graph</div><div class="category" '
#  'data-v-a172066e>Miscellaneous</div></div><!--]--></li><!--]--><!--[--><li '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:center;min-width:0;" '
#  'data-v-a172066e><!--[--><div data-v-a172066e><div class="name" '
#  'data-v-a172066e>MacOS</div><div class="category" data-v-a172066e>Operating '
#  'Systems &amp; Computing '
#  'Languages</div></div><!--]--></li><!--]--><!--[--><li '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:center;min-width:0;" '
#  'data-v-a172066e><!--[--><div data-v-a172066e><div class="name" '
#  'data-v-a172066e>Gatling</div><div class="category" data-v-a172066e>Testing '
#  'And Qa</div></div><!--]--></li><!--]--><!--[--><li '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:center;min-width:0;" '
#  'data-v-a172066e><!--[--><div data-v-a172066e><div class="name" '
#  'data-v-a172066e>Video.js</div><div class="category" data-v-a172066e>Video '
#  'Players</div></div><!--]--></li><!--]--><!--[--><li '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:center;min-width:0;" '
#  'data-v-a172066e><!--[--><div data-v-a172066e><div class="name" '
#  'data-v-a172066e>Adobe Creative Suite</div><div class="category" '
#  'data-v-a172066e>Visualisation '
#  'Software</div></div><!--]--></li><!--]--><!--]--></ul><!--]--><!--]--><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:space-between;min-width:0;" '
#  'class="cta" data-v-c6d691d1><!--[--><div class="left" '
#  'data-v-c6d691d1><!--[--><!--]--></div><div '
#  'data-v-c6d691d1><!--[--><!--]--><!----></div><!--]--></div></div><div '
#  'class="card" id="media" title="Media &amp; News" data-v-c617f00a '
#  'data-v-c6d691d1><h2 '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-c6d691d1><!--[--><!----><span data-v-c6d691d1><!--[-->Media &amp; '
#  'News<!--]--></span><!--]--></h2><!--[--><div class="container" '
#  'data-v-c617f00a data-v-9d6c8b2a><ul data-v-9d6c8b2a><!--[--><!--[--><li '
#  'data-v-9d6c8b2a><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:9.52px;justify-content:start;min-width:0;" '
#  'data-v-9d6c8b2a><!--[--><img alt="Media icon" '
#  'src="/_assets/media.BMJLsbkg.svg" data-v-9d6c8b2a><div data-v-9d6c8b2a><a '
#  'href="https://www.prnewswire.com/news-releases/98point6-technologies-announces-the-acquisition-of-brightmd-to-accelerate-the-launch-of-its-asynchronous-care-module-302034295.html" '
#  'rel="nofollow noopener noreferrer" target="_blank" '
#  'data-v-9d6c8b2a><!--[--><h3 data-v-9d6c8b2a>98point6 Inc. will acquire '
#  'Bright.md on Oct 1st &#39;24.</h3><p data-v-9d6c8b2a>98point6 Technologies '
#  'announces the acquisition of Bright.md to accelerate the launch of its '
#  'asynchronous care module.</p><p class="info" data-v-9d6c8b2a><span '
#  'data-v-9d6c8b2a>Jan 15, 2024 | </span><span '
#  'data-v-9d6c8b2a>www.prnewswire.com</span></p><!--]--></a></div><!--]--></div></li><!--]--><!--[--><li '
#  'data-v-9d6c8b2a><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:9.52px;justify-content:start;min-width:0;" '
#  'data-v-9d6c8b2a><!--[--><img alt="Media icon" '
#  'src="/_assets/media.BMJLsbkg.svg" data-v-9d6c8b2a><div data-v-9d6c8b2a><a '
#  'href="https://www.prnewswire.com/news-releases/98point6-technologies-collaborates-with-steadymd-to-offer-comprehensive-virtual-care-solution-to-healthcare-organizations-301950173.html" '
#  'rel="nofollow noopener noreferrer" target="_blank" '
#  'data-v-9d6c8b2a><!--[--><h3 data-v-9d6c8b2a>98point6 Inc. partners with '
#  'SteadyMD, Inc..</h3><p data-v-9d6c8b2a>98point6 Technologies collaborates '
#  'with SteadyMD to offer comprehensive virtual care solution to Healthcare '
#  'Organizations.</p><p class="info" data-v-9d6c8b2a><span data-v-9d6c8b2a>Oct '
#  '08, 2023 | </span><span '
#  'data-v-9d6c8b2a>www.prnewswire.com</span></p><!--]--></a></div><!--]--></div></li><!--]--><!--[--><li '
#  'data-v-9d6c8b2a><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:9.52px;justify-content:start;min-width:0;" '
#  'data-v-9d6c8b2a><!--[--><img alt="Media icon" '
#  'src="/_assets/media.BMJLsbkg.svg" data-v-9d6c8b2a><div data-v-9d6c8b2a><a '
#  'href="https://www.axios.com/pro/health-tech-deals/2023/04/12/98point6-32m-pivots-provider-tech-licensor" '
#  'rel="nofollow noopener noreferrer" target="_blank" '
#  'data-v-9d6c8b2a><!--[--><h3 data-v-9d6c8b2a>98point6 Inc. receives financing '
#  'of $32M.</h3><p data-v-9d6c8b2a>With the ink still drying on a deal to sell '
#  'most of its assets to care navigator Transcarent, telehealth company '
#  '98point6 is raising $32 million, CEO Jay Burrell tells Axios '
#  'exclusively.</p><p class="info" data-v-9d6c8b2a><span data-v-9d6c8b2a>Apr '
#  '12, 2023 | </span><span '
#  'data-v-9d6c8b2a>www.axios.com</span></p><!--]--></a></div><!--]--></div></li><!--]--><!--[--><li '
#  'data-v-9d6c8b2a><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:9.52px;justify-content:start;min-width:0;" '
#  'data-v-9d6c8b2a><!--[--><img alt="Media icon" '
#  'src="/_assets/media.BMJLsbkg.svg" data-v-9d6c8b2a><div data-v-9d6c8b2a><a '
#  'href="https://www.geekwire.com/2022/telehealth-startup-98point6-raises-20m-inks-deal-with-health-system-to-license-tech/" '
#  'rel="nofollow noopener noreferrer" target="_blank" '
#  'data-v-9d6c8b2a><!--[--><h3 data-v-9d6c8b2a>98point6 Inc. partnered with '
#  'MultiCare Health System on Sep 1st &#39;23.</h3><p '
#  'data-v-9d6c8b2a>Seattle-based 98point6 announced that it is licensing its '
#  'virtual care delivery platform in a deal with Tacoma, Wash.-based MultiCare '
#  'Health System.</p><p class="info" data-v-9d6c8b2a><span data-v-9d6c8b2a>Jan '
#  '29, 2023 | </span><span '
#  'data-v-9d6c8b2a>www.geekwire.com</span></p><!--]--></a></div><!--]--></div></li><!--]--><!--[--><li '
#  'data-v-9d6c8b2a><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:9.52px;justify-content:start;min-width:0;" '
#  'data-v-9d6c8b2a><!--[--><img alt="Media icon" '
#  'src="/_assets/media.BMJLsbkg.svg" data-v-9d6c8b2a><div data-v-9d6c8b2a><a '
#  'href="https://www.axios.com/pro/health-tech-deals/2022/09/01/98point6-raises-20m-to-power-health-systems-with-virtual-care" '
#  'rel="nofollow noopener noreferrer" target="_blank" '
#  'data-v-9d6c8b2a><!--[--><h3 data-v-9d6c8b2a>Activant Capital Group invests '
#  'into 98point6 Inc. in the amount of $20M.</h3><p data-v-9d6c8b2a>98point6, a '
#  'text-based virtual care startup, raised an additional $20 million-plus from '
#  'insiders L Catterton and Activant Capital.</p><p class="info" '
#  'data-v-9d6c8b2a><span data-v-9d6c8b2a>Sep 01, 2022 | </span><span '
#  'data-v-9d6c8b2a>www.axios.com</span></p><!--]--></a></div><!--]--></div></li><!--]--><!--[--><li '
#  'data-v-9d6c8b2a><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:9.52px;justify-content:start;min-width:0;" '
#  'data-v-9d6c8b2a><!--[--><img alt="Media icon" '
#  'src="/_assets/media.BMJLsbkg.svg" data-v-9d6c8b2a><div data-v-9d6c8b2a><a '
#  'href="https://www.bizjournals.com/seattle/news/2022/06/09/print-psbj-interview-98point6s-dr-brad-younggren.html" '
#  'rel="nofollow noopener noreferrer" target="_blank" '
#  'data-v-9d6c8b2a><!--[--><h3 data-v-9d6c8b2a>98point6 Inc. hired Younggren as '
#  'president on Jan 1st &#39;17.</h3><p data-v-9d6c8b2a>Younggren joined '
#  '98point6 in 2017 as CMO and he was named president in February.</p><p '
#  'class="info" data-v-9d6c8b2a><span data-v-9d6c8b2a>Jun 09, 2022 | '
#  '</span><span '
#  'data-v-9d6c8b2a>www.bizjournals.com</span></p><!--]--></a></div><!--]--></div></li><!--]--><!--[--><li '
#  'data-v-9d6c8b2a><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:9.52px;justify-content:start;min-width:0;" '
#  'data-v-9d6c8b2a><!--[--><img alt="Media icon" '
#  'src="/_assets/media.BMJLsbkg.svg" data-v-9d6c8b2a><div data-v-9d6c8b2a><a '
#  'href="https://www.globenewswire.com/news-release/2021/08/12/2279790/0/en/XpresSpa-Group-Announces-Agreement-with-98point6-as-the-Treat-Partner-for-Virtual-Care.html" '
#  'rel="nofollow noopener noreferrer" target="_blank" '
#  'data-v-9d6c8b2a><!--[--><h3 data-v-9d6c8b2a>XpresSpa partnered with 98point6 '
#  'Inc. on Aug 12th &#39;21.</h3><p data-v-9d6c8b2a>XpresSpa Group, Inc. '
#  '(Nasdaq: XSPA) (“XpresSpa” or the “Company”), a health and wellness company, '
#  'today announced an agreement with 98point6, an on-demand virtual primary '
#  'care provider, to provide services for the new Treat™ Care app.</p><p '
#  'class="info" data-v-9d6c8b2a><span data-v-9d6c8b2a>Aug 12, 2021 | '
#  '</span><span '
#  'data-v-9d6c8b2a>www.globenewswire.com</span></p><!--]--></a></div><!--]--></div></li><!--]--><!--]--></ul></div><!--]--><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:space-between;min-width:0;" '
#  'class="cta" data-v-c6d691d1><!--[--><div class="left" '
#  'data-v-c6d691d1><!--[--><!--]--></div><div '
#  'data-v-c6d691d1><!--[--><!--]--><!----></div><!--]--></div></div><div '
#  'class="card" id="email" data-v-c617f00a data-v-c6d691d1><h2 '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'data-v-c6d691d1><!--[--><!----><span data-v-c6d691d1><!--[--><span '
#  'data-v-c617f00a>98point6 Technologies Inc.</span>&#39;s Email Address '
#  'Formats<!--]--></span><!--]--></h2><!--[--><!--[--><div '
#  'data-v-055562da><!--[--><div><span>98point6 Technologies Inc.</span> uses at '
#  'least 1 format(s):</div><!--]--></div><table data-v-055562da '
#  'data-v-e5f646e3><!--[--><thead data-v-055562da><tr data-v-055562da><td '
#  'data-v-055562da><span data-v-055562da>98point6 Technologies Inc.</span> '
#  'Email Formats</td><td class="hide-on-mobile" data-v-055562da>Example</td><td '
#  'data-v-055562da>Percentage</td></tr></thead><tbody '
#  'data-v-055562da><!--[--><!--[--><!--[--><!--[--><tr class="" '
#  'data-v-055562da><td data-v-055562da>First@98point6.com</td><td '
#  'class="hide-on-mobile" data-v-055562da>John@98point6.com</td><td '
#  'data-v-055562da><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:6px;justify-content:start;min-width:0;" '
#  'data-v-055562da><!--[--><span class="percent" '
#  'data-v-055562da>58%</span><progress class="hide-on-mobile" '
#  'value="0.5779569892473119" '
#  'data-v-055562da></progress><!--]--></div></td></tr><!--]--><!--[--><tr '
#  'class="" data-v-055562da><td data-v-055562da>First.Last@98point6.com</td><td '
#  'class="hide-on-mobile" data-v-055562da>John.Doe@98point6.com</td><td '
#  'data-v-055562da><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:6px;justify-content:start;min-width:0;" '
#  'data-v-055562da><!--[--><span class="percent" '
#  'data-v-055562da>28%</span><progress class="hide-on-mobile" '
#  'value="0.27956989247311825" '
#  'data-v-055562da></progress><!--]--></div></td></tr><!--]--><!--[--><tr '
#  'class="" data-v-055562da><td data-v-055562da>Last@98point6.com</td><td '
#  'class="hide-on-mobile" data-v-055562da>Doe@98point6.com</td><td '
#  'data-v-055562da><div '
# ...
#  'class="title" data-v-2c5e8248>Executive Assistant To Chief Executive '
#  'Officer</div><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:16px;justify-content:start;min-width:0;" '
#  'class="details hide-on-mobile" data-v-2c5e8248><!--[--><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'class="item mobile" data-v-2c5e8248><!--[--><img alt="Phone icon" '
#  'src="/_assets/phone.VY-Lk3As.svg" data-v-2c5e8248><a target="_blank" '
#  'href="https://account.leadiq.com/signup/welcome?utm_source=seo&amp;fp=%2Fsearch%2Fresults%3FcompanyId%3DMergedCompany-5a1d98e42300005400877e7d%26companyName%3D98point6%2BTechnologies%2BInc.%26personId%3DPersonID-2201c6ed-7074-4708-99ff-95eb754068a1" '
#  'data-v-2c5e8248><!--[-->Mobile Phone<!--]--></a><!--]--></div><div '
#  'class="separator" data-v-2c5e8248></div><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'class="item email" data-v-2c5e8248><!--[--><img alt="Envelope icon" '
#  'src="/_assets/email-verified.CQm0m087.svg" data-v-2c5e8248><a '
#  'target="_blank" '
#  'href="https://account.leadiq.com/signup/welcome?utm_source=seo&amp;fp=%2Fsearch%2Fresults%3FcompanyId%3DMergedCompany-5a1d98e42300005400877e7d%26companyName%3D98point6%2BTechnologies%2BInc.%26personId%3DPersonID-2201c6ed-7074-4708-99ff-95eb754068a1" '
#  'data-v-2c5e8248><!--[-->Email<!--]--></a><!--]--></div><!--]--></div><!----><!--]--></div><!--]--></li><li '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:16px;justify-content:start;min-width:0;" '
#  'data-v-0af0051d data-v-2c5e8248><!--[--><img alt="Stylized image of a '
#  'person" src="/_assets/person2.gGAFDQux.svg" data-v-2c5e8248><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:column;flex-wrap:nowrap;gap:0px;justify-content:start;min-width:0;" '
#  'class="info" data-v-2c5e8248><!--[--><div class="name" '
#  'data-v-2c5e8248><strong data-v-2c5e8248>J. S.</strong></div><div '
#  'class="title" data-v-2c5e8248>Executive Assistant To Chief Executive '
#  'Officer</div><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:16px;justify-content:start;min-width:0;" '
#  'class="details hide-on-mobile" data-v-2c5e8248><!--[--><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'class="item mobile" data-v-2c5e8248><!--[--><img alt="Phone icon" '
#  'src="/_assets/phone.VY-Lk3As.svg" data-v-2c5e8248><a target="_blank" '
#  'href="https://account.leadiq.com/signup/welcome?utm_source=seo&amp;fp=%2Fsearch%2Fresults%3FcompanyId%3DMergedCompany-5a1d98e42300005400877e7d%26companyName%3D98point6%2BTechnologies%2BInc.%26personId%3DPersonID-757003e4-801b-4c5f-9fb6-132d078edcc3" '
#  'data-v-2c5e8248><!--[-->Mobile Phone<!--]--></a><!--]--></div><div '
#  'class="separator" data-v-2c5e8248></div><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'class="item email" data-v-2c5e8248><!--[--><img alt="Envelope icon" '
#  'src="/_assets/email-verified.CQm0m087.svg" data-v-2c5e8248><a '
#  'target="_blank" '
#  'href="https://account.leadiq.com/signup/welcome?utm_source=seo&amp;fp=%2Fsearch%2Fresults%3FcompanyId%3DMergedCompany-5a1d98e42300005400877e7d%26companyName%3D98point6%2BTechnologies%2BInc.%26personId%3DPersonID-757003e4-801b-4c5f-9fb6-132d078edcc3" '
#  'data-v-2c5e8248><!--[-->Email<!--]--></a><!--]--></div><!--]--></div><!----><!--]--></div><!--]--></li><li '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:16px;justify-content:start;min-width:0;" '
#  'data-v-0af0051d data-v-2c5e8248><!--[--><img alt="Stylized image of a '
#  'person" src="/_assets/person1.BPMEtw_v.svg" data-v-2c5e8248><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:column;flex-wrap:nowrap;gap:0px;justify-content:start;min-width:0;" '
#  'class="info" data-v-2c5e8248><!--[--><div class="name" '
#  'data-v-2c5e8248><strong data-v-2c5e8248>J. M.</strong></div><div '
#  'class="title" data-v-2c5e8248>Professor Of Cardiology Hofstra School Of '
#  'Medicine And Chief Diversity Officer Northwell Health</div><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:16px;justify-content:start;min-width:0;" '
#  'class="details hide-on-mobile" data-v-2c5e8248><!--[--><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'class="item mobile" data-v-2c5e8248><!--[--><img alt="Phone icon" '
#  'src="/_assets/phone.VY-Lk3As.svg" data-v-2c5e8248><a target="_blank" '
#  'href="https://account.leadiq.com/signup/welcome?utm_source=seo&amp;fp=%2Fsearch%2Fresults%3FcompanyId%3DMergedCompany-5a1d98e42300005400877e7d%26companyName%3D98point6%2BTechnologies%2BInc.%26personId%3DPersonWLID-d711330e-4d4b-47cf-bfdb-a072abaa8b8d" '
#  'data-v-2c5e8248><!--[-->Mobile Phone<!--]--></a><!--]--></div><div '
#  'class="separator" data-v-2c5e8248></div><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:8px;justify-content:start;min-width:0;" '
#  'class="item email" data-v-2c5e8248><!--[--><img alt="Envelope icon" '
#  'src="/_assets/email-verified.CQm0m087.svg" data-v-2c5e8248><a '
#  'target="_blank" '
#  'href="https://account.leadiq.com/signup/welcome?utm_source=seo&amp;fp=%2Fsearch%2Fresults%3FcompanyId%3DMergedCompany-5a1d98e42300005400877e7d%26companyName%3D98point6%2BTechnologies%2BInc.%26personId%3DPersonWLID-d711330e-4d4b-47cf-bfdb-a072abaa8b8d" '
#  'data-v-2c5e8248><!--[-->Email<!--]--></a><!--]--></div><!--]--></div><!----><!--]--></div><!--]--></li><!--]--></ul><!--]--><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:space-between;min-width:0;" '
#  'class="cta" data-v-c6d691d1><!--[--><div class="left" '
#  'data-v-c6d691d1><!--[--><!--]--></div><div data-v-c6d691d1><!--[--><a '
#  'href="/c/98point6-technologies-inc/5a1d98e42300005400877e7d/employee-directory" '
#  'data-v-c617f00a><!--[-->Go to Employee Directory<!--]--></a><!--]--><img '
#  'alt="Arrow icon" class="arrow" src="/_assets/cta-arrow.DS0e8PRD.svg" '
#  'data-v-c6d691d1></div><!--]--></div></div><!--]--></div><div '
#  'class="sidebar-bottom" data-v-00c368dc><!--[--><section data-v-c617f00a '
#  'data-v-d599a7a5><h3 data-v-d599a7a5>Ready to create more pipeline?</h3><p '
#  'data-v-d599a7a5>Get a demo and discover why thousands of SDR and Sales teams '
#  'trust LeadIQ to help them build pipeline confidently.</p><a target="_blank" '
#  'href="https://account.leadiq.com/signup/welcome?utm_source=seo&amp;fp=%2Fsearch%2Fresults%3FcompanyId%3DMergedCompany-5a1d98e42300005400877e7d%26companyName%3D98point6%2BTechnologies%2BInc." '
#  'data-v-d599a7a5><!--[--><button data-v-d599a7a5>Sign me '
#  'up</button><!--]--></a></section><!--]--></div><!--]--></div></div><!--[--><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:center;min-width:0;" '
#  'class="container cta wrap" data-v-f2ce2197><!--[--><section '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:space-between;min-width:0;" '
#  'data-v-f2ce2197 data-v-f236162f><!--[--><div data-v-f236162f><h3 '
#  'data-v-f236162f>Ready to create more pipeline?</h3><p data-v-f236162f>Get a '
#  'demo and discover why thousands of SDR and Sales teams trust<br '
#  'data-v-f236162f>LeadIQ to help them build pipeline confidently.</p></div><a '
#  'target="_blank" '
#  'href="https://account.leadiq.com/signup/welcome?utm_source=seo&amp;fp=%2Fsearch%2Fresults%3FcompanyId%3DMergedCompany-5a1d98e42300005400877e7d%26companyName%3D98point6%2BTechnologies%2BInc." '
#  'class="link" data-v-f236162f><!--[--><a target="_blank" '
#  'href="https://leadiq.com/book-a-demo?utm_source=seo" '
#  'data-v-f236162f><!--[--><button data-v-f236162f>Book a '
#  'demo</button><!--]--></a><!--]--></a><!--]--></section><!--]--></div><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:center;min-width:0;" '
#  'class="wrap" data-v-f2ce2197><!--[--><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:16px;justify-content:space-between;min-width:0;" '
#  'class="container top wrap" data-v-f2ce2197><!--[--><ul data-v-f2ce2197><li '
#  'data-v-f2ce2197>Platform</li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/identify-prospect-data" data-v-f2ce2197>Identify '
#  'prospect data</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/track-sales-triggers" data-v-f2ce2197>Track sales '
#  'triggers</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/scribe-generative-ai-for-sales" '
#  'data-v-f2ce2197>Compose personalized messages</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/enrich-salesforce-data" data-v-f2ce2197>Enrich '
#  'Salesforce data</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/success-stories" data-v-f2ce2197>Success '
#  'Stories</a></li></ul><ul data-v-f2ce2197><li '
#  'data-v-f2ce2197>Resources</li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/pricing" data-v-f2ce2197>Pricing</a></li><li '
#  'data-v-f2ce2197><a href="https://leadiq.com/blog" '
#  'data-v-f2ce2197>Blog</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/c/company-search" data-v-f2ce2197>Company '
#  'Search</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiqhelp.zendesk.com/hc/en-us" '
#  'data-v-f2ce2197>Support</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/careers" data-v-f2ce2197>Careers</a></li><li '
#  'data-v-f2ce2197><a href="https://leadiq.com/data-community" '
#  'data-v-f2ce2197>Data Community</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/our-data" data-v-f2ce2197>Our Data</a></li><li '
#  'data-v-f2ce2197><a href="https://leadiq.com/privacy-center" '
#  'data-v-f2ce2197>Privacy Center</a></li></ul><ul data-v-f2ce2197><li '
#  'data-v-f2ce2197>Legal</li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/legal/privacy-policy" data-v-f2ce2197>Privacy '
#  'Policy</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/legal/cookie-policy" data-v-f2ce2197>Cookie '
#  'Policy</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/legal/terms-of-use" data-v-f2ce2197>Terms of '
#  'Service</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/privacy-center" data-v-f2ce2197>Do Not Sell or '
#  'Share My Personal Information</a></li></ul><ul class="noflex" '
#  'data-v-f2ce2197><li data-v-f2ce2197>Compare</li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/compare/leadiq-vs-zoominfo" data-v-f2ce2197>LeadIQ '
#  'vs. Zoominfo</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/compare/leadiq-vs-apollo" data-v-f2ce2197>LeadIQ '
#  'vs. Apollo</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/compare/compare-leadiq-vs-lusha" '
#  'data-v-f2ce2197>LeadIQ vs. Lusha</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/compare/compare-leadiq-vs-cognism" '
#  'data-v-f2ce2197>LeadIQ vs. Cognism</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/compare/leadiq-vs-seamless-ai" '
#  'data-v-f2ce2197>LeadIQ vs. Seamless.ai</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/compare/leadiq-vs-usergems" data-v-f2ce2197>LeadIQ '
#  'vs. Usergems</a></li><li data-v-f2ce2197><a '
#  'href="https://leadiq.com/compare/leadiq-vs-champify" data-v-f2ce2197>LeadIQ '
#  'vs. Champify</a></li></ul><ul data-v-f2ce2197><li '
#  'data-v-f2ce2197>Contact</li><li data-v-f2ce2197><a '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:10px;justify-content:start;min-width:0;" '
#  'onclick="window.location.href = &#39;tel:18886532347&#39;" '
#  'data-v-f2ce2197><!--[--><img '
#  'src="https://assets-global.website-files.com/60819f9be381394642b5659e/6081c958408db1111a5f6e4b_leadiq-icon-contact-phone.svg" '
#  'loading="eager" alt="Vectorized stroke icon of a phone that links to the '
#  'LeadIQ phone dial number." data-v-f2ce2197>1-888-653-2347 '
#  '<!--]--></a></li><li data-v-f2ce2197><a '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:10px;justify-content:start;min-width:0;" '
#  'onclick="window.location.href = &#39;mailto:support@leadiq.com&#39;" '
#  'data-v-f2ce2197><!--[--><img '
#  'src="https://assets-global.website-files.com/60819f9be381394642b5659e/6081c9584a52ae9f54e9d71c_leadiq-icon-contact-email.svg" '
#  'loading="eager" alt="Vectorized stroke icon of a mail that links to the '
#  'LeadIQ customer support address." data-v-f2ce2197>support@leadiq.com '
#  '<!--]--></a></li><li data-v-f2ce2197><a '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:10px;justify-content:start;min-width:0;" '
#  'onclick="window.location.href = &#39;mailto:support@leadiq.com&#39;" '
#  'data-v-f2ce2197><!--[--><img '
#  'src="https://assets-global.website-files.com/60819f9be381394642b5659e/6081c9584a52ae9f54e9d71c_leadiq-icon-contact-email.svg" '
#  'loading="eager" alt="Vectorized stroke icon of a mail that links to the '
#  'LeadIQ customer support address." class="icon-contact" '
#  'data-v-f2ce2197>sales@leadiq.com '
#  '<!--]--></a></li></ul><!--]--></div><!--]--></div><div '
#  'style="align-items:start;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:center;min-width:0;" '
#  'class="wrap" data-v-f2ce2197><!--[--><div '
#  'style="align-items:center;display:flex;flex:1;flex-direction:row;flex-wrap:nowrap;gap:0px;justify-content:space-between;min-width:0;" '
#  'class="container bottom" data-v-f2ce2197><!--[--><span data-v-f2ce2197>© '
#  'LeadIQ, Inc. All rights reserved.</span><div class="container-right-footer" '
#  'data-v-f2ce2197><a href="https://www.facebook.com/leadiq" rel="nofollow '
#  'noopener noreferrer" target="_blank" class="social-media facebook '
#  'w-inline-block" data-v-f2ce2197><!--[--><img '
#  'src="https://assets-global.website-files.com/60819f9be381394642b5659e/6081cb4e5452d50f1f7a3fb3_leadiq-social-media-facebook.svg" '
#  'loading="eager" alt="Logo of the company Facebook that links directly to the '
#  'LeadIQ Facebook page." data-v-f2ce2197><!--]--></a><a '
#  'href="https://twitter.com/leadiq" rel="nofollow noopener noreferrer" '
#  'target="_blank" class="social-media twitter w-inline-block" '
#  'data-v-f2ce2197><!--[--><img '
#  'src="https://assets-global.website-files.com/60819f9be381394642b5659e/6081cb4eee94984fa4071d52_leadiq-social-media-twitter.svg" '
#  'loading="eager" alt="Logo of the company Twitter that links directly to the '
#  'LeadIQ Twitter page." data-v-f2ce2197><!--]--></a><a '
#  'href="https://www.linkedin.com/company/leadiq-inc/" rel="nofollow noopener '
#  'noreferrer" target="_blank" class="social-media linkedin w-inline-block" '
#  'data-v-f2ce2197><!--[--><img '
#  'src="https://assets-global.website-files.com/60819f9be381394642b5659e/6081cb4e288f5700bcb39bfd_leadiq-social-media-linkedin.svg" '
#  'loading="eager" alt="Logo of the company LinkedIn that links directly to the '
#  'LeadIQ LinkedIn page." data-v-f2ce2197><!--]--></a><a '
#  'href="https://www.youtube.com/channel/UCNb5aT5w8EIMX4QKFuFL_Yg" '
#  'rel="nofollow noopener noreferrer" target="_blank" class="social-media '
#  'youtube w-inline-block" data-v-f2ce2197><!--[--><img '
#  'src="https://assets-global.website-files.com/60819f9be381394642b5659e/6081cb4e9e444d3a934f9719_leadiq-social-media-youtube.svg" '
#  'loading="eager" alt="Logo of the company Youtube that links directly to the '
#  'LeadIQ Youtube page." '
#  'data-v-f2ce2197><!--]--></a></div><!--]--></div><!--]--></div><!--]--><!--]--></div><!--]-->  '
#  '<!-- anchor highlighting in nav -->  <!-- viewport intersection -->  <!-- '
#  'list filtering -->  </body> </html> ')

# %%
import json
import re

def find_hidden_data(result: ScrapeApiResponse) -> dict:
    """
    Extract hidden web cache (Apollo Graphql framework) from Glassdoor page HTML
    It's either in NEXT_DATA script or direct apolloState js variable
    """
    # data can be in __NEXT_DATA__ cache
    data = result.selector.css("script#__NEXT_DATA__::text").get()
    if data:
        data = json.loads(data)["props"]["pageProps"]["apolloCache"]
    else:  # or in direct apolloState cache
        data = re.findall(r'apolloState":\s*({.+})};', result.content)[0]
        data = json.loads(data)

    def _unpack_apollo_data(apollo_data):
        """
        Glassdoor uses Apollo GraphQL client and the dataset is a graph of references.
        This function unpacks the __ref references to actual values.
        """

        def resolve_refs(data, root):
            if isinstance(data, dict):
                if "__ref" in data:
                    return resolve_refs(root[data["__ref"]], root)
                else:
                    return {k: resolve_refs(v, root) for k, v in data.items()}
            elif isinstance(data, list):
                return [resolve_refs(i, root) for i in data]
            else:
                return data

        return resolve_refs(apollo_data.get("ROOT_QUERY") or apollo_data, apollo_data)

    return _unpack_apollo_data(data)

cache = find_hidden_data(scrapfly_result.content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 38
#      34         return resolve_refs(apollo_data.get("ROOT_QUERY") or apollo_data, apollo_data)
#      36     return _unpack_apollo_data(data)
# ---> 38 cache = find_hidden_data(scrapfly_result.content)
#
# Cell In[18], line 10, in find_hidden_data(result)
#       5 """
#       6 Extract hidden web cache (Apollo Graphql framework) from Glassdoor page HTML
#       7 It's either in NEXT_DATA script or direct apolloState js variable
#       8 """
#       9 # data can be in __NEXT_DATA__ cache
# ---> 10 data = result.selector.css("script#__NEXT_DATA__::text").get()
#      11 if data:
#      12     data = json.loads(data)["props"]["pageProps"]["apolloCache"]
#
# AttributeError: 'str' object has no attribute 'selector'

# %%
# maybe try newspaper4k?
import newspaper
from news.scrape import remove_img_tags

article = newspaper.article(
    url,
    language="en",
    # Remove images to prevent downloading them, which crashes
    input_html=remove_img_tags(scrapfly_result.content),
    fetch_images=False,
)
article.parse()

article

# %%
print(article.text)
# Out:
# Acquisition Strategy 98point6 Technologies has been actively acquiring strategic companies like Bright.md to enhance its virtual care capabilities, presenting potential partnership opportunities for cross-selling services to a larger combined customer base.
#
# Funding and Expansion With recent financing of $32 million and partnerships with organizations like MultiCare Health System, 98point6 is in a strong position to expand its reach, indicating potential sales opportunities for new clients seeking innovative virtual care solutions.
#
# Technology Integration The tech stack utilized by 98point6, including tools like HubSpot Chat and Pardot, showcases a commitment to leveraging advanced technologies, creating avenues for sales discussions around integrated solutions for healthcare organizations.
#
# Key Personnel Impact The appointment of Younggren as president brings significant experience to the team, potentially opening doors for sales conversations with prospects looking for leadership-backed assurances and tailored virtual care services.
